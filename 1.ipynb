# %%
import warnings
warnings.filterwarnings('ignore')
from task1 import solve

# %%
solve(32)
# Out:
# C_err: 0.0011985517854554706
# L_2_err: 0.020052307398077205

# %%
solve(64)
# Out:
# C_err: 0.0003006507813647641
# L_2_err: 0.010021479952006803

# %%
solve(128)
# Out:
# C_err: 7.525915812300887e-05
# L_2_err: 0.005010155236201988
